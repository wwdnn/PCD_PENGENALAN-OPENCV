# %%
# Wildan Setya Nugraha  -  211511032
# Task 1 - Image Processing

import cv2
from PIL import Image
import cv2  
from IPython.display import display

# %%
# membaca gambar
img = cv2.imread('../GAMBAR/tantangan.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#Cek Nilai Piksel
width = img.shape[0]
height = img.shape[1]

print("width: ", width, "px")
print("height: ", height, "px")
# Out:
# width:  583 px
# height:  595 px

# %%
#Mengubah Warna Segilima menjadi RGB (255,255,0) --> Kuning
img[np.where((img == [255,0,0]).all(axis = 2))] = [255,255,0]

#display the image
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=595x583>

# %%
#Mengubah Warna Segitiga menjadi RGB (0,255,255) --> Biru Muda
img[np.where((img == [0,255,0]).all(axis = 2))] = [0,255,255]

#display the image
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=595x583>

# %%
#Mengubah Warna Awan menjadi RGB (255,0,255) --> Ungu/Pink
img[np.where((img == [0,0,255]).all(axis = 2))] = [255,0,255]

#display the image
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=595x583>
